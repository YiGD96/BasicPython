# %% [raw]
# anscombe data 셋 : 시각화

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
type(anscombe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')
plt.plot(dataset_2['x'],dataset_2['y'],'o')
plt.plot(dataset_3['x'],dataset_3['y'],'o')
plt.plot(dataset_4['x'],dataset_4['y'],'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)    #2행 2열 1번째
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')

# %%
print(dataset_1['x'].mean(), dataset_1['x'].max(), dataset_1['x'].std(), dataset_1['x'].var())
print(dataset_1.corr())
print(dataset_2['x'].mean(), dataset_2['x'].max(), dataset_2['x'].std(), dataset_2['x'].var())
print(dataset_2.corr())
print(dataset_3['x'].mean(), dataset_3['x'].max(), dataset_3['x'].std(), dataset_3['x'].var())
print(dataset_3.corr())
print(dataset_4['x'].mean(), dataset_4['x'].max(), dataset_4['x'].std(), dataset_4['x'].var())
print(dataset_4.corr())
# Out:
# 9.0 14.0 3.3166247903554 11.0
#           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000
# 9.0 14.0 3.3166247903554 11.0
#           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000
# 9.0 14.0 3.3166247903554 11.0
#           x         y
# x  1.000000  0.816287
# y  0.816287  1.000000
# 9.0 19.0 3.3166247903554 11.0
#           x         y
# x  1.000000  0.816521
# y  0.816521  1.000000
